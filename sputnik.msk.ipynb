# %%
#Import Library
import folium
from folium import plugins

#Create base map
map = folium.Map(location=[55.7558,37.6177], zoom_start = 10, tiles = "Stamen Toner")

def add_marker(arr, color_1, color_2):    
    for i in range(0, len(arr)):
        el = arr[i]
        if arr[i]['main_icon'] == True:
            folium.Marker(location=[el['loc_1'],el['loc_2']], popup=el['title'], icon=folium.Icon(color=color_1)).add_to(map)
        else:
            folium.CircleMarker(location=[el['loc_1'],el['loc_2']], popup=el['title'],\
                               radius = 9, fill=True, fill_color=color_2, color=None, fill_opacity = 1).add_to(map)

# %%
blue_line = [
    {'title': "Белорусский вокзал", 'main_icon': True, 'loc_1': 55.7769, 'loc_2': 37.5815},
    {'title': "Беговая  (станция)", 'main_icon': False, 'loc_1': 55.773244, 'loc_2': 37.550517},
    {'title': "Фили (станция)", 'main_icon': False, 'loc_1': 55.744256, 'loc_2': 37.515334},
    {'title': "Трёхгорка (станция)", 'main_icon': False, 'loc_1': 55.697338, 'loc_2': 37.338911},
    {'title': "Одинцово (станция)", 'main_icon': True, 'loc_1': 55.672189, 'loc_2': 37.281532},
    {'title': "Жаворонки (станция)", 'main_icon': False, 'loc_1': 55.641834, 'loc_2': 37.096936},
    {'title': "Голицыно (станция)", 'main_icon': False, 'loc_1': 55.615088, 'loc_2': 36.986890},
    {'title': "Кубинка I ", 'main_icon': False, 'loc_1': 55.578951, 'loc_2': 36.691036}, 
    {'title': "Тучково (станция)", 'main_icon': False, 'loc_1': 55.597623, 'loc_2': 36.468428}, 
    {'title': "Дорохово (станция)", 'main_icon': False, 'loc_1': 55.546825, 'loc_2': 36.373427}, 
    {'title': "Можайск (станция)", 'main_icon': True, 'loc_1': 55.494209, 'loc_2': 36.032641},    
    {'title': "Звенигород (станция)", 'main_icon': True, 'loc_1': 55.700587, 'loc_2': 36.881142}
]

# %%
purple_line = [
    {'title': "Казанский вокзал", 'main_icon': True, 'loc_1': 55.773444, 'loc_2': 37.655329},
    {'title': "Выхино (станция)", 'main_icon': False, 'loc_1': 55.716052, 'loc_2': 37.816263},
    {'title': "Люберцы I (станция)", 'main_icon': False, 'loc_1': 55.682365, 'loc_2': 37.897613},
    {'title': "Отдых (станция)", 'main_icon': False, 'loc_1': 55.601722, 'loc_2': 38.136491},
    {'title': "Раменское (станция)", 'main_icon': True, 'loc_1': 55.565330, 'loc_2': 38.226015},           
    {'title': "Бронницы (станция)", 'main_icon': False, 'loc_1': 55.498424, 'loc_2': 38.362496},
    {'title': "Белоозёрский (станция)", 'main_icon': False, 'loc_1': 55.462083, 'loc_2': 38.449485},
    {'title': "Виноградово (станция)", 'main_icon': False, 'loc_1': 55.426942, 'loc_2': 38.560097},
    {'title': "Конобеево (станция)", 'main_icon': False, 'loc_1': 55.405737, 'loc_2': 38.656123},
    {'title': "88 км (станция)", 'main_icon': False, 'loc_1': 55.327188, 'loc_2': 38.685730},
    {'title': "Москворецкая (станция)", 'main_icon': False, 'loc_1': 55.270327, 'loc_2': 38.744059},
    {'title': "Цемгигант (станция)", 'main_icon': False, 'loc_1': 55.251002, 'loc_2': 38.755797},
    {'title': "Пески (станция)", 'main_icon': False, 'loc_1': 55.215171, 'loc_2': 38.771734},
    {'title': "Хорошёво (станция)", 'main_icon': False, 'loc_1': 55.143653, 'loc_2': 38.787158},
    {'title': "Коломна (станция)", 'main_icon': False, 'loc_1': 55.098879, 'loc_2': 38.781035},
    {'title': "Голутвин (станция)", 'main_icon': True, 'loc_1': 55.086148, 'loc_2': 38.805210},
    {'title': "Луховицы (станция)", 'main_icon': False, 'loc_1': 54.982344, 'loc_2': 39.041702},
    {'title': "Фруктовая (станция)", 'main_icon': False, 'loc_1': 54.916170, 'loc_2': 39.258164},
    {'title': "Рыбное (станция)", 'main_icon': False, 'loc_1': 54.730806, 'loc_2': 39.504199},
    {'title': "Рязань I (станция)", 'main_icon': True, 'loc_1': 54.633240, 'loc_2': 39.713018},    
    {'title': "Коренёво (станция)", 'main_icon': False, 'loc_1': 55.668069, 'loc_2': 38.000693},
    {'title': "Гжель (станция)", 'main_icon': False, 'loc_1': 55.609075, 'loc_2': 38.446438},
    {'title': "Куровская (станция)", 'main_icon': True, 'loc_1': 55.573447, 'loc_2': 38.923133}
]

# %%
red_line = [
    {'title': "Москва-Каланчёвская (станция)", 'main_icon': True, 'loc_1': 55.775773, 'loc_2': 37.652112},   
    {'title': "Текстильщики (станция)", 'main_icon': False, 'loc_1': 55.707084, 'loc_2': 37.729587},
    {'title': "Царицыно (станция)", 'main_icon': True, 'loc_1': 55.618379, 'loc_2': 37.669055},
    {'title': "Силикатная (станция)", 'main_icon': False, 'loc_1': 55.470425, 'loc_2': 37.555466},
    {'title': "Подольск (станция)", 'main_icon': True, 'loc_1': 55.432241, 'loc_2': 37.565152},
    {'title': "Гривно (станция)", 'main_icon': False, 'loc_1': 55.357005, 'loc_2': 37.526817},
    {'title': "Львовская (станция)", 'main_icon': False, 'loc_1': 55.312411, 'loc_2': 37.515673},
    {'title': "Столбовая (станция)", 'main_icon': False, 'loc_1': 55.248337, 'loc_2': 37.493481},
    {'title': "Чехов (станция)", 'main_icon': False, 'loc_1': 55.149747, 'loc_2': 37.490059},
    {'title': "Серпухов (станция)", 'main_icon': True, 'loc_1': 54.934730, 'loc_2': 37.451382}
]

red_line_2 = [         
    {'title': "Тарусская (станция)", 'main_icon': False, 'loc_1': 54.735090, 'loc_2': 37.400711},
    {'title': "Ясногорск (станция)", 'main_icon': False, 'loc_1': 54.479016, 'loc_2': 37.685234},
    {'title': "Тула I-Курская (станция)", 'main_icon': True, 'loc_1': 54.199386, 'loc_2': 37.577344}
]

# %%
orange_line = [
    {'title': "Киевский вокзал", 'main_icon': True, 'loc_1': 55.743059, 'loc_2': 37.567884},      
    {'title': "Переделкино (станция)", 'main_icon': False, 'loc_1': 55.656313, 'loc_2': 37.355634},
    {'title': "Кокошкино (станция)", 'main_icon': False, 'loc_1': 55.599800, 'loc_2': 37.171300},
    {'title': "Апрелевка (станция)", 'main_icon': False, 'loc_1': 55.550159, 'loc_2': 37.066905},
    {'title': "Селятино (станция)", 'main_icon': False, 'loc_1': 55.516499, 'loc_2': 36.967068},
    {'title': "Нара (станция)", 'main_icon': False, 'loc_1': 55.383370, 'loc_2': 36.751126},
    {'title': "Балабаново (станция)", 'main_icon': False, 'loc_1': 55.178863, 'loc_2': 36.661889},
    {'title': "Обнинское (станция)", 'main_icon': False, 'loc_1': 55.092012, 'loc_2': 36.618509},
    {'title': "Малоярославец (станция)", 'main_icon': True, 'loc_1': 55.007707, 'loc_2': 36.480759},   
    {'title': "Суходрев (станция)", 'main_icon': False, 'loc_1': 54.806777, 'loc_2': 36.319433},
    {'title': "Муратовка (станция)", 'main_icon': False, 'loc_1': 54.619254, 'loc_2': 36.156768},
    {'title': "Азарово (станция)", 'main_icon': False, 'loc_1': 54.565416, 'loc_2': 36.244438},
    {'title': "Калуга I (станция)", 'main_icon': True, 'loc_1': 54.533334, 'loc_2': 36.278488},    
    {'title': "Очаково (станция)", 'main_icon': False, 'loc_1': 55.682892, 'loc_2': 37.451457},
    {'title': "Сколково (станция)", 'main_icon': False, 'loc_1': 55.667052, 'loc_2': 37.425651},
    {'title': "Солнечная (станция)", 'main_icon': False, 'loc_1': 55.656508, 'loc_2': 37.384432},
    {'title': "Новопеределкино (станция)", 'main_icon': True, 'loc_1': 55.637854, 'loc_2': 37.383471}
]

# %%
gray_line = [
    {'title': "Курский вокзал", 'main_icon': True, 'loc_1': 55.756992, 'loc_2': 37.661239},
    {'title': "Карачарово (станция)", 'main_icon': False, 'loc_1': 55.733209, 'loc_2': 37.729534},  
    {'title': "Железнодорожная (станция)", 'main_icon': True, 'loc_1': 55.752022, 'loc_2': 38.008352},
    {'title': "Фрязево (станция)", 'main_icon': False, 'loc_1': 55.732362, 'loc_2': 38.465488},
    {'title': "Павловский Посад (станция)", 'main_icon': False, 'loc_1': 55.775796, 'loc_2': 38.674756},
    {'title': "Орехово-Зуево (станция)", 'main_icon': True, 'loc_1': 55.795849, 'loc_2': 38.976144},
    {'title': "Петушки (станция)", 'main_icon': True, 'loc_1': 55.924704, 'loc_2': 39.462841},
    {'title': "Костерёво (станция)", 'main_icon': False, 'loc_1': 55.929794, 'loc_2': 39.619697},
    {'title': "Болдино (станция)", 'main_icon': False, 'loc_1': 55.952967, 'loc_2': 39.737247},
    {'title': "Сушнево (станция)", 'main_icon': False, 'loc_1': 55.960298, 'loc_2': 39.777558},
    {'title': "Ундол (станция)", 'main_icon': False, 'loc_1': 56.020208, 'loc_2': 39.983619},
    {'title': "Колокша (станция)", 'main_icon': False, 'loc_1': 56.062027, 'loc_2': 40.184897},
    {'title': "Юрьевец (станция)", 'main_icon': False, 'loc_1': 56.092707, 'loc_2': 40.280170},
    {'title': "Владимир (станция)", 'main_icon': True, 'loc_1': 56.130215, 'loc_2': 40.420069},  
    {'title': "Электросталь (станция)", 'main_icon': False, 'loc_1': 55.786916, 'loc_2': 38.460394},
    {'title': "Машиностроитель (станция)", 'main_icon': False, 'loc_1': 55.801217, 'loc_2': 38.454571},
    {'title': "Ногинск (станция)", 'main_icon': True, 'loc_1': 55.850938, 'loc_2': 38.443552},
] 

gray_line_2 = [
    {'title': "Дмитровская (станция)", 'main_icon': False, 'loc_1': 55.808010, 'loc_2': 37.578666},
    {'title': "Красный Балтиец (станция)", 'main_icon': False, 'loc_1': 55.815501, 'loc_2': 37.526369},
    {'title': "Ленинградская (станция)", 'main_icon': False, 'loc_1': 55.815255, 'loc_2': 37.490073},
    {'title': "Тушино (станция)", 'main_icon': False, 'loc_1': 55.827297, 'loc_2': 37.439691},
    {'title': "Павшино (станция)", 'main_icon': False, 'loc_1': 55.815618, 'loc_2': 37.341853},
    {'title': "Опалиха (станция)", 'main_icon': False, 'loc_1': 55.823384, 'loc_2': 37.246793},
    {'title': "Нахабино (станция)", 'main_icon': False, 'loc_1': 55.841671, 'loc_2': 37.185223},
    {'title': "Дедовск (станция)", 'main_icon': False, 'loc_1': 55.866600, 'loc_2': 37.125717},
    {'title': "Снегири (станция)", 'main_icon': False, 'loc_1': 55.880189, 'loc_2': 37.037991},
    {'title': "Манихино I (станция)", 'main_icon': False, 'loc_1': 55.890534, 'loc_2': 36.929443},
    {'title': "Истра (станция)", 'main_icon': False, 'loc_1': 55.903873, 'loc_2': 36.856100},
    {'title': "Новоиерусалимская (станция)", 'main_icon': False, 'loc_1': 55.911880, 'loc_2': 36.823021},
    {'title': "Холщёвики (станция)", 'main_icon': False, 'loc_1': 55.926426, 'loc_2': 36.701651},
    {'title': "Румянцево (станция)", 'main_icon': False, 'loc_1': 55.973555, 'loc_2': 36.541422},
    {'title': "Новопетровская (станция)", 'main_icon': False, 'loc_1': 55.996477, 'loc_2': 36.472369},
    {'title': "Чисмена (станция)", 'main_icon': False, 'loc_1': 56.018162, 'loc_2': 36.214067},
    {'title': "Волоколамск (станция)", 'main_icon': False, 'loc_1': 55.993671, 'loc_2': 35.935780},
    {'title': "Шаховская (станция)", 'main_icon': True, 'loc_1': 56.029873, 'loc_2': 35.511452}
]

# %%
green_line = [
    {'title': "Ленинградский вокзал", 'main_icon': True, 'loc_1': 55.776452, 'loc_2': 37.655217},   
    {'title': "Химки (станция)", 'main_icon': False, 'loc_1': 55.894340, 'loc_2': 37.452520},
    {'title': "Сходня (станция)", 'main_icon': False, 'loc_1': 55.949628, 'loc_2': 37.298610},
    {'title': "Крюково (станция)", 'main_icon': True, 'loc_1': 55.979927, 'loc_2': 37.173784},
    {'title': "Подсолнечная (станция)", 'main_icon': False, 'loc_1': 56.184236, 'loc_2': 36.971547},
    {'title': "Клин (станция)", 'main_icon': False, 'loc_1': 56.332486, 'loc_2': 36.710292},
    {'title': "Завидово (станция)", 'main_icon': False, 'loc_1': 56.551179, 'loc_2': 36.438934},
    {'title': "Редкино (станция)", 'main_icon': False, 'loc_1': 56.645550, 'loc_2': 36.295377},
    {'title': "Чуприяновка (станция)", 'main_icon': False, 'loc_1': 56.756614, 'loc_2': 36.041201},
    {'title': "Тверь (станция)", 'main_icon': True, 'loc_1': 56.835474, 'loc_2': 35.892109}
]

# %%
lightred_line = [
    {'title': "Павелецкий вокзал", 'main_icon': True, 'loc_1': 55.729827, 'loc_2': 37.640599},
    {'title': "Верхние Котлы (станция) ", 'main_icon': False, 'loc_1': 55.690214, 'loc_2': 37.619314},
    {'title': "Нижние Котлы (станция)", 'main_icon': False, 'loc_1': 55.682384, 'loc_2': 37.621298},
    {'title': "Коломенское (станция)", 'main_icon': False, 'loc_1': 55.654901, 'loc_2': 37.622252},
    {'title': "Бирюлёво-Пассажирская (станция)", 'main_icon': False, 'loc_1': 55.582978, 'loc_2': 37.659630},
    {'title': "Расторгуево (станция)", 'main_icon': False, 'loc_1': 55.548342, 'loc_2': 37.685886},
    {'title': "Домодедово (станция)", 'main_icon': True, 'loc_1': 55.439435, 'loc_2': 37.773333},
    {'title': "Белые Столбы (станция)", 'main_icon': False, 'loc_1': 55.333744, 'loc_2': 37.850397},
    {'title': "Барыбино (станция)", 'main_icon': True, 'loc_1': 55.269547, 'loc_2': 37.895589},
    {'title': "Михнево (станция)", 'main_icon': False, 'loc_1': 55.121340, 'loc_2': 37.960037},
    {'title': "Жилёво (станция)", 'main_icon': False, 'loc_1': 54.986459, 'loc_2': 38.030863},  
    {'title': "Ступино (станция)", 'main_icon': False, 'loc_1': 54.908150, 'loc_2': 38.078793},
    {'title': "Кашира (станция)", 'main_icon': False, 'loc_1': 54.857535, 'loc_2': 38.189342},
    {'title': "Тесна (станция)", 'main_icon': False, 'loc_1': 54.830359, 'loc_2': 38.243765},
    {'title': "Ожерелье (станция)", 'main_icon': True, 'loc_1': 54.801491, 'loc_2': 38.272710}
]

# %%
beige_line = [
    {'title': "Савёловский вокзал", 'main_icon': True, 'loc_1': 55.794445, 'loc_2': 37.588248},   
    {'title': "Окружная (станция)", 'main_icon': False, 'loc_1': 55.847675, 'loc_2': 37.574314},
    {'title': "Долгопрудная (станция)", 'main_icon': False, 'loc_1': 55.938454, 'loc_2': 37.520658},
    {'title': "Лобня (станция)", 'main_icon': True, 'loc_1': 56.013189, 'loc_2': 37.484545},
    {'title': "Дмитров (станция)", 'main_icon': True, 'loc_1': 56.337584, 'loc_2': 37.510265},
    {'title': "Вербилки (станция)", 'main_icon': False, 'loc_1': 56.539109, 'loc_2': 37.560031},
    {'title': "Большая Волга (станция)", 'main_icon': False, 'loc_1': 56.726907, 'loc_2': 37.136617},
    {'title': "Дубна (станция)", 'main_icon': True, 'loc_1': 56.746048, 'loc_2': 37.200530}
]

# %%
pink_line_1 = [
    {'title': "Ярославский вокзал", 'main_icon': True, 'loc_1': 55.776475, 'loc_2': 37.657736},
    {'title': "Лосиноостровская (станция)", 'main_icon': False, 'loc_1': 55.862240, 'loc_2': 37.681882},    
    {'title': "Мытищи (станция)", 'main_icon': True, 'loc_1': 55.914472, 'loc_2': 37.762222},
    {'title': "Подлипки-Дачные (станция)", 'main_icon': False, 'loc_1': 55.925820, 'loc_2': 37.816978},
    {'title': "Болшево (станция)", 'main_icon': True, 'loc_1': 55.926196, 'loc_2': 37.861042},
    {'title': "Загорянская (станция)", 'main_icon': False, 'loc_1': 55.926460, 'loc_2': 37.916212},
    {'title': "Воронок (станция)", 'main_icon': False, 'loc_1': 55.919119, 'loc_2': 37.973931},
    {'title': "Чкаловская (станция)", 'main_icon': False, 'loc_1': 55.897156, 'loc_2': 38.063112},
    {'title': "Бахчиванджи (станция)", 'main_icon': False, 'loc_1': 55.882637, 'loc_2': 38.083601},
    {'title': "Монино (станция)", 'main_icon': True, 'loc_1': 55.843384, 'loc_2': 38.199290},
]

pink_line_2 = [
    {'title': "Пушкино (станция)", 'main_icon': True, 'loc_1': 56.012482, 'loc_2': 37.839240},
    {'title': "Софрино (станция)", 'main_icon': False, 'loc_1': 56.135228, 'loc_2': 37.929492},
    {'title': "Хотьково (станция)", 'main_icon': False, 'loc_1': 56.256616, 'loc_2': 37.996142},
    {'title': "Сергиев Посад (станция)", 'main_icon': True, 'loc_1': 56.302002, 'loc_2': 38.136389}, 
    {'title': "Струнино (станция)", 'main_icon': False, 'loc_1': 56.378626, 'loc_2': 38.587398},
    {'title': "Александров I (станция)", 'main_icon': True, 'loc_1': 56.398153, 'loc_2': 38.704148}
]

pink_line_3 = [
    {'title': "Ивантеевка-2 (станция)", 'main_icon': False, 'loc_1': 55.961734, 'loc_2': 37.908300},
    {'title': "Фрязино (станция)", 'main_icon': True, 'loc_1': 55.963253, 'loc_2': 38.044631}
]

# %%
add_marker(blue_line,'darkblue', 'blue')
add_marker(purple_line,'darkpurple', 'purple')
add_marker(red_line,'red', 'red')
add_marker(red_line_2,'darkred', 'darkred')
add_marker(orange_line,'orange', 'orange')
add_marker(gray_line,'gray', 'gray')
add_marker(gray_line_2,'gray', 'gray')
add_marker(green_line,'green', 'green')
add_marker(lightred_line,'lightred', '#ef9a9a')
add_marker(beige_line,'beige', '#ffe0b2')
add_marker(pink_line_1,'pink', '#ea80fc')
add_marker(pink_line_2,'pink', '#ea80fc')
add_marker(pink_line_3,'pink', '#ea80fc')

# %%
purple_poly_line_1 = [
    [purple_line[0]['loc_1'], purple_line[0]['loc_2']],
    [purple_line[1]['loc_1'], purple_line[1]['loc_2']],
    [purple_line[2]['loc_1'], purple_line[2]['loc_2']],
    [purple_line[3]['loc_1'], purple_line[3]['loc_2']],
    [purple_line[4]['loc_1'], purple_line[4]['loc_2']],
    [purple_line[5]['loc_1'], purple_line[5]['loc_2']],
    [purple_line[6]['loc_1'], purple_line[6]['loc_2']],
    [purple_line[7]['loc_1'], purple_line[7]['loc_2']],
    [purple_line[8]['loc_1'], purple_line[8]['loc_2']],
    [purple_line[9]['loc_1'], purple_line[9]['loc_2']],
    [purple_line[10]['loc_1'], purple_line[10]['loc_2']],
    [purple_line[11]['loc_1'], purple_line[11]['loc_2']],
    [purple_line[12]['loc_1'], purple_line[12]['loc_2']],
    [purple_line[13]['loc_1'], purple_line[13]['loc_2']],
    [purple_line[14]['loc_1'], purple_line[14]['loc_2']],
    [purple_line[15]['loc_1'], purple_line[15]['loc_2']],
    [purple_line[16]['loc_1'], purple_line[16]['loc_2']],
    [purple_line[17]['loc_1'], purple_line[17]['loc_2']],
    [purple_line[18]['loc_1'], purple_line[18]['loc_2']],
    [purple_line[19]['loc_1'], purple_line[19]['loc_2']]
]

purple_poly_line_2 = [
    [purple_line[2]['loc_1'], purple_line[2]['loc_2']],
    [purple_line[20]['loc_1'], purple_line[20]['loc_2']],
    [purple_line[21]['loc_1'], purple_line[21]['loc_2']],
    [purple_line[22]['loc_1'], purple_line[22]['loc_2']]
]

red_poly_line = [
    [red_line[0]['loc_1'], red_line[0]['loc_2']],
    [gray_line[0]['loc_1'], gray_line[0]['loc_2']],
    [red_line[1]['loc_1'], red_line[1]['loc_2']],
    [red_line[2]['loc_1'], red_line[2]['loc_2']],
    [red_line[3]['loc_1'], red_line[3]['loc_2']],
    [red_line[4]['loc_1'], red_line[4]['loc_2']],
    [red_line[5]['loc_1'], red_line[5]['loc_2']],
    [red_line[6]['loc_1'], red_line[6]['loc_2']],
    [red_line[7]['loc_1'], red_line[7]['loc_2']],
    [red_line[8]['loc_1'], red_line[8]['loc_2']],
    [red_line[9]['loc_1'], red_line[9]['loc_2']]
]

orange_poly_line_1 = [
    [orange_line[0]['loc_1'], orange_line[0]['loc_2']],
    [orange_line[1]['loc_1'], orange_line[1]['loc_2']],
    [orange_line[2]['loc_1'], orange_line[2]['loc_2']],
    [orange_line[3]['loc_1'], orange_line[3]['loc_2']],
    [orange_line[4]['loc_1'], orange_line[4]['loc_2']],
    [orange_line[5]['loc_1'], orange_line[5]['loc_2']],
    [orange_line[6]['loc_1'], orange_line[6]['loc_2']],
    [orange_line[7]['loc_1'], orange_line[7]['loc_2']],
    [orange_line[8]['loc_1'], orange_line[8]['loc_2']],
    [orange_line[9]['loc_1'], orange_line[9]['loc_2']],
    [orange_line[10]['loc_1'], orange_line[10]['loc_2']],
    [orange_line[11]['loc_1'], orange_line[11]['loc_2']],
    [orange_line[12]['loc_1'], orange_line[12]['loc_2']],
]

orange_poly_line_2 = [
    [orange_line[0]['loc_1'], orange_line[0]['loc_2']],
    [orange_line[13]['loc_1'], orange_line[13]['loc_2']],
    [orange_line[14]['loc_1'], orange_line[14]['loc_2']],
    [orange_line[15]['loc_1'], orange_line[15]['loc_2']],
    [orange_line[16]['loc_1'], orange_line[16]['loc_2']]
]

blue_poly_line_1 = [
    [blue_line[0]['loc_1'], blue_line[0]['loc_2']],
    [blue_line[1]['loc_1'], blue_line[1]['loc_2']],
    [blue_line[2]['loc_1'], blue_line[2]['loc_2']],
    [blue_line[3]['loc_1'], blue_line[3]['loc_2']],
    [blue_line[4]['loc_1'], blue_line[4]['loc_2']],
    [blue_line[5]['loc_1'], blue_line[5]['loc_2']],
    [blue_line[6]['loc_1'], blue_line[6]['loc_2']],
    [blue_line[7]['loc_1'], blue_line[7]['loc_2']],
    [blue_line[8]['loc_1'], blue_line[8]['loc_2']],
    [blue_line[9]['loc_1'], blue_line[9]['loc_2']],
    [blue_line[10]['loc_1'], blue_line[10]['loc_2']]
]

blue_poly_line_2 = [
    [blue_line[6]['loc_1'], blue_line[6]['loc_2']],
    [blue_line[11]['loc_1'], blue_line[11]['loc_2']]
]

gray_poly_line_1 = [
    [gray_line[0]['loc_1'], gray_line[0]['loc_2']],
    [gray_line[1]['loc_1'], gray_line[1]['loc_2']],
    [gray_line[2]['loc_1'], gray_line[2]['loc_2']],
    [gray_line[3]['loc_1'], gray_line[3]['loc_2']],
    [gray_line[4]['loc_1'], gray_line[4]['loc_2']],
    [gray_line[5]['loc_1'], gray_line[5]['loc_2']],
    [gray_line[6]['loc_1'], gray_line[6]['loc_2']],
    [gray_line[7]['loc_1'], gray_line[7]['loc_2']],
    [gray_line[8]['loc_1'], gray_line[8]['loc_2']],
    [gray_line[9]['loc_1'], gray_line[9]['loc_2']],
    [gray_line[10]['loc_1'], gray_line[10]['loc_2']],
    [gray_line[11]['loc_1'], gray_line[11]['loc_2']],
    [gray_line[12]['loc_1'], gray_line[12]['loc_2']],
    [gray_line[13]['loc_1'], gray_line[13]['loc_2']]
]

gray_poly_line_2 = [
    [gray_line[3]['loc_1'], gray_line[3]['loc_2']],
    [gray_line[14]['loc_1'], gray_line[14]['loc_2']],
    [gray_line[15]['loc_1'], gray_line[15]['loc_2']],
    [gray_line[16]['loc_1'], gray_line[16]['loc_2']]
]

gray_poly_line_3 = [
    [gray_line[0]['loc_1'], gray_line[0]['loc_2']],
    [gray_line_2[0]['loc_1'], gray_line_2[0]['loc_2']],
    [gray_line_2[1]['loc_1'], gray_line_2[1]['loc_2']],
    [gray_line_2[2]['loc_1'], gray_line_2[2]['loc_2']],
    [gray_line_2[3]['loc_1'], gray_line_2[3]['loc_2']],
    [gray_line_2[4]['loc_1'], gray_line_2[4]['loc_2']],
    [gray_line_2[5]['loc_1'], gray_line_2[5]['loc_2']],
    [gray_line_2[6]['loc_1'], gray_line_2[6]['loc_2']],
    [gray_line_2[7]['loc_1'], gray_line_2[7]['loc_2']],
    [gray_line_2[8]['loc_1'], gray_line_2[8]['loc_2']],
    [gray_line_2[9]['loc_1'], gray_line_2[9]['loc_2']],
    [gray_line_2[10]['loc_1'], gray_line_2[10]['loc_2']],
    [gray_line_2[11]['loc_1'], gray_line_2[11]['loc_2']],
    [gray_line_2[12]['loc_1'], gray_line_2[12]['loc_2']],
    [gray_line_2[13]['loc_1'], gray_line_2[13]['loc_2']],
    [gray_line_2[14]['loc_1'], gray_line_2[14]['loc_2']],
    [gray_line_2[15]['loc_1'], gray_line_2[15]['loc_2']],
    [gray_line_2[16]['loc_1'], gray_line_2[16]['loc_2']],
    [gray_line_2[17]['loc_1'], gray_line_2[17]['loc_2']]
]

gray_red_poly_line_1 = [
    [gray_line[0]['loc_1'], gray_line[0]['loc_2']],
    [red_line[2]['loc_1'], red_line[2]['loc_2']],
    [red_line[4]['loc_1'], red_line[4]['loc_2']],
    [red_line[9]['loc_1'], red_line[9]['loc_2']],
    [red_line_2[0]['loc_1'], red_line_2[0]['loc_2']],
    [red_line_2[1]['loc_1'], red_line_2[1]['loc_2']],
    [red_line_2[2]['loc_1'], red_line_2[2]['loc_2']] 
]

green_poly_line = [
    [green_line[0]['loc_1'], green_line[0]['loc_2']],
    [green_line[1]['loc_1'], green_line[1]['loc_2']],
    [green_line[2]['loc_1'], green_line[2]['loc_2']],
    [green_line[3]['loc_1'], green_line[3]['loc_2']],
    [green_line[4]['loc_1'], green_line[4]['loc_2']],
    [green_line[5]['loc_1'], green_line[5]['loc_2']],
    [green_line[6]['loc_1'], green_line[6]['loc_2']],
    [green_line[7]['loc_1'], green_line[7]['loc_2']],
    [green_line[8]['loc_1'], green_line[8]['loc_2']],
    [green_line[9]['loc_1'], green_line[9]['loc_2']]
]

lightred_poly_line = [
    [lightred_line[0]['loc_1'], lightred_line[0]['loc_2']],
    [lightred_line[1]['loc_1'], lightred_line[1]['loc_2']],
    [lightred_line[2]['loc_1'], lightred_line[2]['loc_2']],
    [lightred_line[3]['loc_1'], lightred_line[3]['loc_2']],
    [lightred_line[4]['loc_1'], lightred_line[4]['loc_2']],
    [lightred_line[5]['loc_1'], lightred_line[5]['loc_2']],
    [lightred_line[6]['loc_1'], lightred_line[6]['loc_2']],
    [lightred_line[7]['loc_1'], lightred_line[7]['loc_2']],
    [lightred_line[8]['loc_1'], lightred_line[8]['loc_2']],
    [lightred_line[9]['loc_1'], lightred_line[9]['loc_2']],
    [lightred_line[10]['loc_1'], lightred_line[10]['loc_2']],
    [lightred_line[11]['loc_1'], lightred_line[11]['loc_2']],
    [lightred_line[12]['loc_1'], lightred_line[12]['loc_2']],
    [lightred_line[13]['loc_1'], lightred_line[13]['loc_2']],
    [lightred_line[14]['loc_1'], lightred_line[14]['loc_2']]
]

beige_poly_line = [
    [beige_line[0]['loc_1'], beige_line[0]['loc_2']],
    [beige_line[1]['loc_1'], beige_line[1]['loc_2']],
    [beige_line[2]['loc_1'], beige_line[2]['loc_2']],
    [beige_line[3]['loc_1'], beige_line[3]['loc_2']],
    [beige_line[4]['loc_1'], beige_line[4]['loc_2']],
    [beige_line[5]['loc_1'], beige_line[5]['loc_2']],
    [beige_line[6]['loc_1'], beige_line[6]['loc_2']],
    [beige_line[7]['loc_1'], beige_line[7]['loc_2']]
]

pink_poly_line_1 = [
    [pink_line_1[0]['loc_1'], pink_line_1[0]['loc_2']],
    [pink_line_1[1]['loc_1'], pink_line_1[1]['loc_2']],
    [pink_line_1[2]['loc_1'], pink_line_1[2]['loc_2']],
    [pink_line_1[3]['loc_1'], pink_line_1[3]['loc_2']],
    [pink_line_1[4]['loc_1'], pink_line_1[4]['loc_2']],
    [pink_line_1[5]['loc_1'], pink_line_1[5]['loc_2']],
    [pink_line_1[6]['loc_1'], pink_line_1[6]['loc_2']],
    [pink_line_1[7]['loc_1'], pink_line_1[7]['loc_2']],
    [pink_line_1[8]['loc_1'], pink_line_1[8]['loc_2']],
    [pink_line_1[9]['loc_1'], pink_line_1[9]['loc_2']] 
]

pink_poly_line_2 = [
    [pink_line_1[2]['loc_1'], pink_line_1[2]['loc_2']],
    [pink_line_2[0]['loc_1'], pink_line_2[0]['loc_2']],
    [pink_line_2[1]['loc_1'], pink_line_2[1]['loc_2']],
    [pink_line_2[2]['loc_1'], pink_line_2[2]['loc_2']],
    [pink_line_2[3]['loc_1'], pink_line_2[3]['loc_2']],
    [pink_line_2[4]['loc_1'], pink_line_2[4]['loc_2']],
    [pink_line_2[5]['loc_1'], pink_line_2[5]['loc_2']]
]

pink_poly_line_3 = [
    [pink_line_1[4]['loc_1'], pink_line_1[4]['loc_2']],
    [pink_line_3[0]['loc_1'], pink_line_3[0]['loc_2']],
    [pink_line_3[1]['loc_1'], pink_line_3[1]['loc_2']]
]

# %%
folium.PolyLine(locations=purple_poly_line_1, color='purple', opacity=0.5, weight=5.5).add_to(map)
folium.PolyLine(locations=purple_poly_line_2, color='purple', opacity=0.5, weight=5.5).add_to(map)
folium.PolyLine(locations=red_poly_line, color='red', opacity=0.5, weight=5.5).add_to(map)
folium.PolyLine(locations=orange_poly_line_1, color='orange', opacity=0.5, weight=5.5).add_to(map)
folium.PolyLine(locations=orange_poly_line_2, color='orange', opacity=0.5, weight=5.5).add_to(map)
folium.PolyLine(locations=blue_poly_line_1, color='blue', opacity=0.5, weight=5.5).add_to(map)
folium.PolyLine(locations=blue_poly_line_2, color='blue', opacity=0.5, weight=5.5).add_to(map)
folium.PolyLine(locations=gray_poly_line_1, color='gray', opacity=0.7, weight=5.5).add_to(map)
folium.PolyLine(locations=gray_poly_line_2, color='gray', opacity=0.7, weight=5.5).add_to(map)
folium.PolyLine(locations=gray_poly_line_3, color='gray', opacity=0.7, weight=5.5).add_to(map)
folium.PolyLine(locations=gray_red_poly_line_1, color='darkred', opacity=0.7, weight=5.5).add_to(map)
folium.PolyLine(locations=green_poly_line, color='green', opacity=0.7, weight=5.5).add_to(map)
folium.PolyLine(locations=lightred_poly_line, color='#ef9a9a', opacity=0.7, weight=5.5).add_to(map)
folium.PolyLine(locations=beige_poly_line, color='#ffe0b2', opacity=0.7, weight=5.5).add_to(map)
folium.PolyLine(locations=pink_poly_line_1, color='#ea80fc', opacity=0.7, weight=5.5).add_to(map)
folium.PolyLine(locations=pink_poly_line_2, color='#ea80fc', opacity=0.7, weight=5.5).add_to(map)
folium.PolyLine(locations=pink_poly_line_3, color='#ea80fc', opacity=0.7, weight=5.5).add_to(map)

# %%
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
plugins.Fullscreen(
    position='topright',
    title='Expand me',
    title_cancel='Exit me',
    force_separate_button=True
).add_to(map)

# %%
#Save the map
map.save("index.html")
